# %%
print("hello world")
# Out:
# hello world

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('species', axis=1 )

# %%
y =df['species']

# %%
X_train , X_test, y_train , y_test =   train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

model_knn = KNeighborsClassifier(n_neighbors=5)

# %%
model_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
model_knn.score(X_test, y_test)
# Out:
# 0.98

# %%
from sklearn.svm import SVC

# %%
model_svm = SVC(C = 30 , kernel='rbf' , gamma=0.1 )

# %%
model_svm.fit(X_train, y_train)
# Out:
# SVC(C=30, gamma=0.1)

# %%
model_svm.score(X_test, y_test)
# Out:
# 0.98

# %% [markdown]
# #change little

# %%
# now lets  use the grid search CV

# %%
model_svm = SVC(C = 30 , kernel='rbf' , gamma='auto' )

# %%
model_svm.fit(X_train, y_train)
# Out:
# SVC(C=30, gamma='auto')

# %%
model_svm.score(X_test, y_test)
# Out:
# 0.98

# %%
classifier =  GridSearchCV( (model_svm) , {
  'C' : [1,10,20,30,40,50],
  'kernel' : ['linear' , 'rbf' , 'poly'],
  
}, cv=5 , return_train_score = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 classifier =  GridSearchCV( (model_svm) , {
#       2   'C' : [1,10,20,30,40,50],
#       3   'kernel' : ['linear' , 'rbf' , 'poly'],
#       4
#       5 }, cv=5 , return_train_score = False)
#
# NameError: name 'GridSearchCV' is not defined

# %%
classifier.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(C=30, gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30, 40, 50],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
results = pd.DataFrame(classifier.cv_results_)

# %%
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.008004      0.002377         0.005798        0.002134        1
# 1        0.008001      0.002097         0.006000        0.001097        1
# 2        0.006801      0.001318         0.003596        0.000487        1
# 3        0.004602      0.000802         0.002797        0.000746       10
# 4        0.003800      0.000400         0.002602        0.000803       10
# 5        0.009197      0.003059         0.003804        0.000749       10
# 6        0.005602      0.001743         0.005600        0.002728       20
# 7        0.010799      0.002481         0.011400        0.002417       20
# 8        0.066200      0.047810         0.015799        0.013581       20
# 9        0.011199      0.001834         0.007602        0.001856       30
# 10       0.012395      0.001630         0.009399        0.002058       30
# 11       0.016404      0.008847         0.004395        0.001023       30
# 12       0.004408      0.001481         0.003393        0.001190       40
# 13       0.003789      0.001148         0.003618        0.001038       40
# 14       0.018799      0.009617         0.003597        0.002254       40
# 15       0.004208      0.001178         0.003388        0.001003       50
# 16       0.004408      0.001031         0.002598        0.000489       50
# 17       0.014788      0.008938         0.003598        0.001347       50
#
#    param_kernel                         params  split0_test_score  \
# 0        linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 1           rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 2          poly     {'C': 1, 'kernel': 'poly'}           1.000000
# 3        linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 4           rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# 5          poly    {'C': 10, 'kernel': 'poly'}           1.000000
# 6        linear  {'C': 20, 'kernel': 'linear'}           1.000000
# 7           rbf     {'C': 20, 'kernel': 'rbf'}           0.966667
# 8          poly    {'C': 20, 'kernel': 'poly'}           0.966667
# 9        linear  {'C': 30, 'kernel': 'linear'}           1.000000
# 10          rbf     {'C': 30, 'kernel': 'rbf'}           0.966667
# 11         poly    {'C': 30, 'kernel': 'poly'}           0.966667
# 12       linear  {'C': 40, 'kernel': 'linear'}           1.000000
# 13          rbf     {'C': 40, 'kernel': 'rbf'}           1.000000
# 14         poly    {'C': 40, 'kernel': 'poly'}           0.966667
# 15       linear  {'C': 50, 'kernel': 'linear'}           1.000000
# 16          rbf     {'C': 50, 'kernel': 'rbf'}           1.000000
# 17         poly    {'C': 50, 'kernel': 'poly'}           0.966667
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            1.000000           0.966667           0.966667
# 1            1.000000           0.966667           0.966667
# 2            1.000000           0.900000           0.933333
# 3            1.000000           0.900000           0.966667
# 4            1.000000           0.966667           0.966667
# 5            1.000000           0.900000           0.933333
# 6            1.000000           0.900000           0.933333
# 7            1.000000           0.900000           0.966667
# 8            0.966667           0.900000           0.933333
# 9            1.000000           0.900000           0.900000
# 10           1.000000           0.900000           0.933333
# 11           0.966667           0.900000           0.933333
# 12           1.000000           0.900000           0.900000
# 13           0.966667           0.900000           0.933333
# 14           0.966667           0.900000           0.933333
# 15           1.000000           0.900000           0.933333
# 16           0.966667           0.900000           0.933333
# 17           0.966667           0.933333           0.933333
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 1.0         0.980000        0.016330                1
# 1                 1.0         0.980000        0.016330                1
# 2                 1.0         0.966667        0.042164                6
# 3                 1.0         0.973333        0.038873                4
# 4                 1.0         0.980000        0.016330                1
# 5                 1.0         0.966667        0.042164                6
# 6                 1.0         0.966667        0.042164                6
# 7                 1.0         0.966667        0.036515                5
# 8                 1.0         0.953333        0.033993               16
# 9                 1.0         0.960000        0.048990               10
# 10                1.0         0.960000        0.038873               10
# 11                1.0         0.953333        0.033993               16
# 12                1.0         0.960000        0.048990               10
# 13                1.0         0.960000        0.038873               10
# 14                1.0         0.953333        0.033993               16
# 15                1.0         0.966667        0.042164                6
# 16                1.0         0.960000        0.038873               10
# 17                1.0         0.960000        0.024944               10

# %%
results[['param_C' , 'param_kernel' , 'mean_test_score']  ]
# Out:
#     param_C param_kernel  mean_test_score
# 0         1       linear         0.980000
# 1         1          rbf         0.980000
# 2         1         poly         0.966667
# 3        10       linear         0.973333
# 4        10          rbf         0.980000
# 5        10         poly         0.966667
# 6        20       linear         0.966667
# 7        20          rbf         0.966667
# 8        20         poly         0.953333
# 9        30       linear         0.960000
# 10       30          rbf         0.960000
# 11       30         poly         0.953333
# 12       40       linear         0.960000
# 13       40          rbf         0.960000
# 14       40         poly         0.953333
# 15       50       linear         0.966667
# 16       50          rbf         0.960000
# 17       50         poly         0.960000

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
classifier_r = RandomizedSearchCV( (model_svm) , {
  'C' : [1,10,20,30], 
  'kernel' : ['linear' , 'rbf' , 'poly'],
}, n_iter = 4 ,  cv=5 , return_train_score = False )

# %%
classifier_r.fit(X,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(C=30, gamma='auto'), n_iter=4,
#                    param_distributions={'C': [1, 10, 20, 30],
#                                         'kernel': ['linear', 'rbf', 'poly']})

# %%
results = pd.DataFrame(classifier_r.cv_results_)

# %%
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.011002      0.001671         0.006998        0.001673          rbf
# 1       0.010793      0.004168         0.007408        0.002649         poly
# 2       0.024198      0.017219         0.004202        0.001167         poly
# 3       0.008605      0.002574         0.005394        0.001491       linear
#
#    param_C                        params  split0_test_score  \
# 0       30    {'kernel': 'rbf', 'C': 30}           0.966667
# 1        1    {'kernel': 'poly', 'C': 1}           1.000000
# 2       20   {'kernel': 'poly', 'C': 20}           0.966667
# 3        1  {'kernel': 'linear', 'C': 1}           0.966667
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           1.000000           0.900000           0.933333                1.0
# 1           1.000000           0.900000           0.933333                1.0
# 2           0.966667           0.900000           0.933333                1.0
# 3           1.000000           0.966667           0.966667                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.960000        0.038873                3
# 1         0.966667        0.042164                2
# 2         0.953333        0.033993                4
# 3         0.980000        0.016330                1

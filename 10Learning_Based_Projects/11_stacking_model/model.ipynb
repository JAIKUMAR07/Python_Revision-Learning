# %% [markdown]
# ## Stacking models
#
# - suppsoe we have 1000 data points
# -  models :  SVM , LR , DT  [ ye saare Base Model hai ]
# - iske model ke pridiciton se meta mdoels bnta
# - suppose meta model [ KNN ] hai
# - ab base model ke prediciton ko KNN model use krta hai
#
# ### agr isme cross fold validation use kre to
# - Base model cross fold val se train hoga to 200 , 200 ,200 ,200 ,200 krke train hoga
# - aur meta learner me 200 , 200 krke 1000 data set outcome ajayega
# - then ab ye 1000 data sets  ko   KNN me train krte hai
# - ab ye meta learner train hoga
# - then yahi meta leaner ka prediction or trained model use hoga

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Cross val me train tes split nhi krte but essemble model me krna pdta hai

# %%
X = df.drop('species', axis=1)
y = df['species']

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %% [markdown]
# ## -> Q.   yaha sochne wali baat ye hai ki agr ye cross val kr rha to train test split q ?
# - to yaha dekhenge to cross val ke karan model to pura data ko dekh leta
# - so hame unseen data me check krwana hai isliye
# - pehle hi 20% data ko alg kr lete jisme kabhi train hoga hi nhi bs test hoga

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42 , stratify = y_encoded )

# %%
base_leaners = [
    ('dt', DecisionTreeClassifier(random_state=42)),
    ('svc', SVC(probability=True, kernel='rbf', random_state=42)), 
    ('lr', LogisticRegression( max_iter=1000))

]

# %%
meta_learner = LogisticRegression(max_iter=1000)

# %%
stacking_clf = StackingClassifier(
  estimators=base_leaners ,
  final_estimator = meta_learner,
  cv=5
)

# %%
stacking_clf.fit(X_train, y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('dt', DecisionTreeClassifier(random_state=42)),
#                                ('svc', SVC(probability=True, random_state=42)),
#                                ('lr', LogisticRegression(max_iter=1000))],
#                    final_estimator=LogisticRegression(max_iter=1000))

# %%
y_pred= stacking_clf.predict(X_test)
# ab iska predcition ko le lenge

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.9666666666666667

# %% [markdown]
# ## Working :

# %% [markdown]
# Bilkul! Tumhare code me **Stacking Classifier** use hua hai — main isko **bilkul easy language me step-by-step** samjha deta hoon taa ki tumhe clearly samajh aa jaye.
#
# ---
#
# # 🌼 **Iris Dataset + Stacking Classifier — Easy Explanation**
#
# ![Image](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Machine%2BLearning%2BR/iris-machinelearning.png?utm_source=chatgpt.com)
#
# ![Image](https://rasbt.github.io/mlxtend/user_guide/classifier/StackingClassifier_files/stackingclassification_overview.png?utm_source=chatgpt.com)
#
# ---
#
# # ⭐ 1. **Dataset Load Karna**
#
# ```python
# df = sns.load_dataset("iris")
# ```
#
# Iris dataset me **flowers ke measurements** hote hain:
#
# * sepal_length
# * sepal_width
# * petal_length
# * petal_width
#   Aur target hota hai: **species** (setosa / versicolor / virginica)
#
# 👉 **Easy meaning:**
# “Hum phoolon ka data load kar rahe hain.”
#
# ---
#
# # ⭐ 2. **Feature (X) aur Target (y) alag karna**
#
# ```python
# X = df.drop('species', axis=1)
# y = df['species']
# ```
#
# 👉 **Easy meaning:**
#
# * X = numbers wale measurements
# * y = flower ka naam
#
# ---
#
# # ⭐ 3. **Label Encoding**
#
# ```python
# le = LabelEncoder()
# y_encoded = le.fit_transform(y)
# ```
#
# Species names ("setosa", etc.) ko **numbers** me convert kiya ja raha hai.
#
# 👉 **Easy meaning:**
# “Text ko numbers me badalna, taki machine samajh sake.”
#
# ---
#
# # ⭐ 4. **Train/Test Split**
#
# ```python
# X_train, X_test, y_train, y_test = train_test_split(..., stratify=y_encoded)
# ```
#
# Data ko 2 parts me baata:
#
# * **Training:** model ko sikhane ke liye
# * **Testing:** model sahi seekha ya nahi check karne ke liye
#
# 👉 **Easy meaning:**
# “Thoda data padhai ke liye, thoda exam ke liye.”
#
# ---
#
# # ⭐ 5. **Base Learners (3 Models)**
#
# ```python
# base_leaners = [
#     ('dt', DecisionTreeClassifier()),
#     ('svc', SVC(probability=True)),
#     ('lr', LogisticRegression())
# ]
# ```
#
# Yeh 3 models niche level par training kar raha hain:
#
# * Decision Tree
# * SVM
# * Logistic Regression
#
# 👉 **Easy meaning:**
# “Teen alag-alag experts banay ja rahe hain jo apni-apni prediction denge.”
#
# ---
#
# # ⭐ 6. **Meta Learner (Final Boss Model)**
#
# ```python
# meta_learner = LogisticRegression()
# ```
#
# Meta learner upar baitha **final decision maker** hota hai.
#
# 👉 **Easy meaning:**
# “Experts ki advice ko combine karke final decision lene wala model.”
#
# ---
#
# # ⭐ 7. **Stacking Classifier Banana**
#
# ```python
# stacking_clf = StackingClassifier(
#     estimators=base_leaners,
#     final_estimator=meta_learner,
#     cv=5
# )
# ```
#
# 👉 **Easy meaning:**
# “Teen models ki prediction ko combine karke ek powerful final model banana.”
#
# ---
#
# # ⭐ 8. **Model Training**
#
# ```python
# stacking_clf.fit(X_train, y_train)
# ```
#
# Sab base models → train
# Meta model → unki prediction ko dekhkar seekhta hai
#
# 👉 **Easy meaning:**
# “Machine ko teamwork se sikhaya ja raha hai.”
#
# ---
#
# # ⭐ 9. **Prediction**
#
# ```python
# y_pred = stacking_clf.predict(X_test)
# ```
#
# Model ab test data ka answer bata raha hai.
#
# 👉 **Easy meaning:**
# “Exam me phool ka naam guess kar raha hai.”
#
# ---
#
# # ⭐ 10. **Accuracy Check**
#
# ```python
# accuracy = accuracy_score(y_test, y_pred)
# accuracy
# ```
#
# 👉 **Easy meaning:**
# “Model ne kitne answers sahi kiye?”
#
# Generally Iris dataset me accuracy ~95–100% aa jati hai.
#
# ---
#
# # 🎉 **Super Simple Summary**
#
# | Step              | Easy Explanation                    |
# | ----------------- | ----------------------------------- |
# | Data Load         | Phoolon ka data lana                |
# | Split             | Padhai aur exam data alag karna     |
# | Encode            | Names → Numbers                     |
# | Train Base Models | 3 alag experts banana               |
# | Meta Model        | Final decision maker                |
# | Stacking          | Experts ki prediction combine karna |
# | Train             | Machine ko teamwork se sikhana      |
# | Predict           | Test answers batana                 |
# | Accuracy          | Sahi jawab ka % check karna         |
#
# ---
#
# Agar tum chaaho to main iska **diagram**, **animations**, ya **visual flow** bhi bana sakta hoon!
# Kya tumhe isi explanation ka **PDF**, **Hindi-only**, ya **even more simple version** chahiye?

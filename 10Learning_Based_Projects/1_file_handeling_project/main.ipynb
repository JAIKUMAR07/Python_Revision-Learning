# %% [markdown]
# ✅ What Does This Mean:
#
# with open(p, "w") as fs:
# This is using the with statement in Python for file handling.
#
# 🧠 Let’s Understand Each Part:
# Part	Meaning
# with	A context manager — it ensures safe opening & closing of resources
# open(p, "w")	Opens the file at path p in write mode
# as fs	Assigns the file object to variable fs (you can name it anything)
#
#
# .
#
# 🔍 What is enumerate() in Python?
# enumerate() is a built-in Python function that adds a counter/index to an iterable (like a list, tuple, or string) and returns it as an enumerate object.
#
# 🧠 Why use enumerate()?
# When you loop through a list and want both:
#
# The index/position (like 0, 1, 2...)
#
# The actual item/value
#
# Instead of this:
#
# python
# Copy
# Edit
# i = 0
# for item in items:
#     print(i, item)
#     i += 1
# You can just write:
#
# python
# Copy
# Edit
# for i, item in enumerate(items):
#     print(i, item)
# Much cleaner!
#
# ✅ Syntax:
#
# enumerate(iterable, start=0)
# iterable: any sequence (like list, tuple, etc.)
#
# start: optional, the starting index (default is 0)
#
# 💡 Example:
#
# items = ["Regression", "Classification", "Clustering"]
#
# for index, value in enumerate(items):
#     print(index, value)
# Output:
# Copy
# Edit
# 0 Regression
# 1 Classification
# 2 Clustering

# %%
# Import Path class from pathlib module for handling file system paths
from pathlib import Path
import os
def readfileandfolder():
    # Create a Path object with empty string to represent current directory
    path = Path("")
    # Use rglob to recursively get all files/folders, convert to list
    items = list(path.rglob("*"))
    # Enumerate through items to display numbered list of files/folders
    for i, items in enumerate(items):
        print(f"{i+1} : {items}")

def createfile():
    # Call readfileandfolder() to show current directory contents
    try:
        readfileandfolder()
        name = input("enter the name of the file ")
        #This does not search for the file named name in the directory.
# Instead, it creates a Path object for the given name — it's just a path reference, not a search.
        p = Path(name)  #  If name = "myfile.txt", then p = Path("myfile.txt") is simply creating a path like:  
        if not p.exists():  # Only check if file doesn't exist
            with open(p , "w") as fs: # us file ko open krenge wirte mode me 
                data = input("what you want to write in this file:- ")
                fs.write(data)
            print("file created successfully")
        else:
            print("file already exists")
#   with	A context manager — it ensures safe opening & closing of resources
#  open(p, "w")	Opens the file at path p in write mode
#  as fs	Assigns the file object to variable fs (you can name it anything)
        
    except Exception as err:
        print(f"An error occurred: {err}")

def readfile():
    try:
        readfileandfolder()
        name = input("which file want to read  ")
        p = Path(name)  # Fixed: use Path instead of path
        if p.exists() and p.is_file():
            with open(p, "r") as fs:
                data = fs.read()
                print(data)
                print("file read successfully")
            
        else:
            print("file does not exist")
    except Exception as err:
        print(f"An error occurred: {err}")

#update file fucntion 

def updatefile():
    try:
        readfileandfolder()
        name = input("which file want to update  ")
        p = Path(name)  # Fixed: use Path instead of path
        if p.exists() and p.is_file():
            print("what you want tp change ")
            print("press 1 : for change type of the file")
            print("press 2 : for overwriting in the file ")
            print("press 3 : for appending in the file ")
            res = int(input("enter your choice: "))

            if res == 1:
                name2 = input("Enter the new name: ")
                p2=path(name2)
                p.rename(p2)

            if res == 2:
                with open(p, "w") as fs:
                    data = input("Enter the new data: ")
                    fs.write(data)
                print("File overwritten successfully")
            if res == 3:
                with open(p, "a") as fs:
                    data = input("Enter what you want to append : ")
                    fs.write(data)
                print("File append successfully")
    except Exception as err:
        print(f"An error occurred: {err}")

def  deletefile():
    try:
        readfileandfolder()
        name = input("which file want to delete  ")
        p = Path(name)  # Fixed: use Path instead of path
        if p.exists() and p.is_file():
            os.remove(p)
            print("file deleted successfully")
        else:
            print("file does not exist")
    except Exception as err:
        print(f"An error occurred: {err}")

# Display menu options to user
print("choose any one ")
print("press 1 for creating  a file")
print("press 2 for reading a file")
print("press 3 for updating a file  ")
print("press 4 for deleting a file")

# Get user input and convert to integer
try:
    check = int(input("enter your choice: "))

    # If user selects option 1, call createfile function
    if check == 1:
        createfile()
    elif check == 2:
        readfile()
    elif check == 3:
        updatefile() 
    elif check == 4:
        deletefile()
    else:
        print("Invalid choice")
except ValueError:
    print("Please enter a valid number")
# Out:
# choose any one
# press 1 for creating  a file
# press 2 for reading a file
# press 3 for updating a file
# press 4 for deleting a file
# 1 : jai
# 2 : main.ipynb
# 3 : rahul
# file deleted successfully

# %%
from pathlib import Path
import os


def readfileandfolder():
    # Create a Path object with empty string  
    path = Path("")
    #   recursively get all files 
    items = list(path.rglob("*"))
    
    for i, items in enumerate(items):
        print(f"{i+1} : {items}")

def createfile():
    try:
        readfileandfolder()
        name = input("enter the name of the file ")
        
 
        p = Path(name) 
        if not p.exists():  
            with open(p , "w") as fs: # us file ko open krenge wirte mode me 
                data = input("what you want to write in this file:- ")
                fs.write(data)
            print("file created successfully")
        else:
            print("file already exists")
    except Exception as err:
        print(f"An error occurred: {err}")

def readfile():
    try:
        readfileandfolder()
        name = input("which file want to read  ")
        p = Path(name)   
        if p.exists() and p.is_file():
            with open(p, "r") as fs:
                data = fs.read()
                print(data)
                print("file read successfully")
        else:
            print("file does not exist")
    except Exception as err:
        print(f"An error occurred: {err}")


def updatefile():
    try:
        readfileandfolder()
        name = input("which file want to update  ")
        p = Path(name)  
        if p.exists() and p.is_file():
            print("what you want tp change ")
            print("press 1 : for change type of the file")
            print("press 2 : for overwriting in the file ")
            print("press 3 : for appending in the file ")
            res = int(input("enter your choice: "))

            if res == 1:
                name2 = input("Enter the new name: ")
                p2=path(name2)
                p.rename(p2)

            if res == 2:
                with open(p, "w") as fs:
                    data = input("Enter the new data: ")
                    fs.write(data)
                print("File overwritten successfully")
            if res == 3:
                with open(p, "a") as fs:
                    data = input("Enter what you want to append : ")
                    fs.write(data)
                print("File append successfully")
    except Exception as err:
        print(f"An error occurred: {err}")


def  deletefile():
    try:
        readfileandfolder()
        name = input("which file want to delete  ")
        p = Path(name)  
        if p.exists() and p.is_file():
            os.remove(p)
            print("file deleted successfully")
        else:
            print("file does not exist")
    except Exception as err:
        print(f"An error occurred: {err}")


while(True):
    # Display menu options to user
    print("choose any one ")
    print("press 1 for creating  a file")
    print("press 2 for reading a file")
    print("press 3 for updating a file  ")
    print("press 4 for deleting a file")
    print("press 5 for exit")

    check = int(input("enter your choice: "))
   
    if check == 1:
        createfile()
    elif check == 2:
        readfile()
    elif check == 3:
        updatefile() 
    elif check == 4:
        deletefile()
    elif check == 5:
        break
    else:
        print("Invalid choice")
# Out:
# choose any one
# press 1 for creating  a file
# press 2 for reading a file
# press 3 for updating a file
# press 4 for deleting a file
# press 5 for exit

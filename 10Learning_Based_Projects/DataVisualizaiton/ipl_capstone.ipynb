# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
print("hii")
# Out:
# hii

# %%
df = pd.read_csv("IPL.csv")

df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %% [markdown]
# BASIC INFO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
df.shape
# Out:
# (74, 20)

# %%
df.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %% [markdown]
# 1 .which team has won most matches

# %%
match_wins = df['match_winner'].value_counts()
sns.barplot( y= match_wins.index , x= match_wins.values)
plt.title("most Match Winner")
# Out:
# Text(0.5, 1.0, 'most Match Winner')

# %% [markdown]
# 2. Toss Deccission

# %%
df.head()

# check ki kya dessision liya jata
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
sns.countplot(x=df['toss_decision'] , palette = 'rainbow')
plt.title("toss winner choice ")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15288\1619560929.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['toss_decision'] , palette = 'rainbow')
# Text(0.5, 1.0, 'toss winner choice ')

# %% [markdown]
# 3. Toss Winner vs Match Winner

# %%
# show sata jo match and toss dono jite 
df[df['toss_winner'] == df['match_winner']].head()
# Out:
#    match_id           date                               venue     team1  \
# 0         1  March 26,2022            Wankhede Stadium, Mumbai   Chennai
# 1         2  March 27,2022           Brabourne Stadium, Mumbai     Delhi
# 2         3  March 27,2022  Dr DY Patil Sports Academy, Mumbai  Banglore
# 3         4  March 28,2022            Wankhede Stadium, Mumbai   Gujarat
# 5         6  March 30,2022  Dr DY Patil Sports Academy, Mumbai  Banglore
#
#      team2  stage toss_winner toss_decision  first_ings_score  \
# 0  Kolkata  Group     Kolkata         Field               131
# 1   Mumbai  Group       Delhi         Field               177
# 2   Punjab  Group      Punjab         Field               205
# 3  Lucknow  Group     Gujarat         Field               158
# 5  Kolkata  Group    Banglore         Field               128
#
#    first_ings_wkts  second_ings_score  second_ings_wkts match_winner   won_by  \
# ...

# %%
 
count = df[df['toss_winner'] == df['match_winner']]['match_id'].count()

percentage = (count * 100 ) / df.shape[0]
percentage.round(2)
# Out:
# 48.65

# %% [markdown]
# 4. How Team Wins ? (Run VS Wickets)

# %%
# category hai      ||  ye automaticly hi counting le lerha 
sns.countplot(x = df['won_by'])
plt.title("won by ")
# Out:
# <Axes: xlabel='won_by', ylabel='count'>

# %% [markdown]
# 5. player of the match who get most ?

# %%
count = df['player_of_the_match'].value_counts().head(10)

sns.barplot(x = count.values , y = count.index)
# Out:
# <Axes: ylabel='player_of_the_match'>

# %% [markdown]
# 6. Top Scorers

# %%
# yaha top scorar ke name and run hai to jb bhi 2 ya  2 se jyada value aye to group by kr dena chahiye 
high = df.groupby('top_scorer')['highscore'].sum()
high

# yaha 2-3 baar aaya tha to group by kr dene pe agragate ho jata group by se
# Out:
# top_scorer
# Abhishek Sharma        122
# Aiden Markram           57
# Andre Russell          119
# David Miller            94
# David Warner           213
# Deepak Hooda           114
# Devon Conway           143
# Dinesh Karthik          66
# Faf du Plessis         257
# Hardik Pandya          154
# Ishan Kishan           180
# Jos Buttler            651
# KL Rahul               351
# Kane Williamson         57
# Liam Livingstone       239
# MS Dhoni                86
# Mitchell Marsh         152
# Moeen Ali               93
# Nitish Rana             57
# Pat Cummins             56
# Quinton de Kock        377
# Rahul Tripathi         147
# Rajat Patidar          112
# Riyan Parag             56
# Ruturaj Gaikwad         99
# Sai Sudharsan           65
# Sanju Samson            54
# Sherfane Rutherford     28
# Shikhar Dhawan         158
# Shimron Hetmyer         59
# Shivam Dube             95
# Shubman Gill           288
# Suryakumar Yadav        68
# Tilak Varma             51
# ...

# %%
# yaha top scorar ke name and run hai to jb bhi 2 ya  2 se jyada value aye to group by kr dena chahiye 
high = df.groupby('top_scorer')['highscore'].sum().sort_values(ascending = False).head(5)
high

# yaha 2-3 baar aaya tha to group by kr dene pe agragate ho jata group by se
# Out:
# top_scorer
# Jos Buttler        651
# Quinton de Kock    377
# KL Rahul           351
# Shubman Gill       288
# Faf du Plessis     257
# Name: highscore, dtype: int64

# %%
high.plot(kind = 'barh')
# Out:
# <Axes: ylabel='top_scorer'>

# %% [markdown]
# 7. 10 best bowling figure

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  ...  second_ings_wkts  match_winner   won_by margin  \
# ...

# %%
# extract 

df['highest_wickets'] = df['best_bowling_figure'].apply(lambda x : x.split('--') [ 0])
df['highest_wickets'] = df['highest_wickets'].astype(int)
top_bowlers = df.groupby('best_bowling')['highest_wickets'].sum().sort_values(ascending = False).head(5)

top_bowlers.plot(kind = 'barh')
# Out:
# <Axes: ylabel='best_bowling'>

# %% [markdown]
# Venue analysis

# %%
venue_count= df['venue'].value_counts()
venue_count
# Out:
# venue
# Wankhede Stadium, Mumbai                        21
# Dr DY Patil Sports Academy, Mumbai              20
# Brabourne Stadium, Mumbai                       16
# Maharashtra Cricket Association Stadium,Pune    13
# Eden Gardens, Kolkata                            2
# Narendra Modi Stadium, Ahmedabad                 2
# Name: count, dtype: int64

# %%
sns.barplot(x = venue_count , y= venue_count.values)
# Out:
# <Axes: xlabel='count'>

# %% [markdown]
# who won the highest margin run

# %%
df [ df['won_by'] == 'Runs'].head()
# Out:
#     match_id           date                                         venue  \
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# 8          9   April 2,2022            Dr DY Patil Sports Academy, Mumbai
# 9         10   April 2,2022  Maharashtra Cricket Association Stadium,Pune
# 10        11   April 3,2022                     Brabourne Stadium, Mumbai
# 11        12   April 4,2022            Dr DY Patil Sports Academy, Mumbai
#
#         team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 4   Hyderabad  Rajasthan  Group   Hyderabad         Field               210
# 8      Mumbai  Rajasthan  Group      Mumbai         Field               193
# 9       Delhi    Gujarat  Group       Delhi         Field               171
# 10    Chennai     Punjab  Group     Chennai         Field               180
# 11  Hyderabad    Lucknow  Group   Hyderabad         Field               169
#
# ...

# %%
df [ df['won_by'] == 'Runs'].sort_values('margin', ascending = False).head()
# Out:
#     match_id           date                                         venue  \
# 54        55     May 8,2022            Dr DY Patil Sports Academy, Mumbai
# 52        53     May 7,2022  Maharashtra Cricket Association Stadium,Pune
# 53        54     May 8,2022                      Wankhede Stadium, Mumbai
# 56        57    May 10,2022  Maharashtra Cricket Association Stadium,Pune
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#         team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 54    Chennai      Delhi  Group       Delhi         Field               208
# 52    Kolkata    Lucknow  Group     Kolkata         Field               176
# 53   Banglore  Hyderabad  Group    Banglore           Bat               192
# 56    Lucknow    Gujarat  Group     Gujarat           Bat               144
# 4   Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
df [ df['won_by'] == 'Runs'].sort_values('margin', ascending = False).head(1)[['match_winner', 'margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %%
df[df['highscore'] == df['highscore'].max()][['top_scorer' ,'highscore']]
# Out:
#          top_scorer  highscore
# 65  Quinton de Kock        140

# %% [markdown]
# which bowler has best bowling ffigure

# %%
df[ df['highest_wickets']== df['highest_wickets'].max()][['best_bowling', 'best_bowling_figure']]
# Out:
#   Cell In[95], line 1
#     df[ df['highest_wickets']== df['highest_wickets'].max()][['best_bowling', 'best_bowling_figure']] ]
#                                                                                                       ^
# SyntaxError: unmatched ']'

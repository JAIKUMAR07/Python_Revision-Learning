# %% [markdown]
# ## Perceptron
#
# A perceptron is the simplest building block of a neural network. It is a mathematical model of a single artificial neuron that takes inputs, processes them, and produces an output. Modern deep learning networks are built by stacking many perceptrons (neurons) into layers.

# %% [markdown]
# ## Machine leanring me :
# - suppose classificaiton me
# - sbse pehle to  y =  mx+ c
#  - then theta
#  - then log loss nikalte
#  - then fir isko km krne ke liye gradient decent bnate
#  - *then global minima lete*
#  - **so in deep learning hum ise hi automate kr dete jo ki ye sb perceptron me hota**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - ab inhi input -> output ke bich agr ek aur layer jod de to banega neural network
# - isi ko ANN kehte hai

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ANN
#
# - each perceptron / nerons connected to another layers each neurons
# - perceptron me hidden layer nhi hota aur sime hidden layer hota
#
#
# - yaha weights W use hota ye diferent  hota jo action ko handle krta
# - like hot water ko chhuye  to turant chhod do
# - cold water aaya koi nhi hold kr skte
# - waise hi value ko aage bhejne me help krta
# - also multipl biases hota
# - jaise  ham theta  me use krte the linear / logistic regression me

# %% [markdown]
# - ab yaha dekh skte hai output 0.5  aya
# - ab isko acha value or prediciton ko perfect krne ke liye
# - weight ko change krna hoga aur ye weight hcange ho skta hai bagpropogation ke through
#
# yaha hamare pass hota
# - activation funcion , loss function [ loss determining ] ->   optimizer  [ relu ]
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## backward propogation :
#
# - ab hum output dekhenge  ab us ouput ka loss nikalenge by using lag loss
# - then ab us loss value ko leke pichhe jayenge
# - then us loss ko km krne ke liye pichhe jate hue network ka weight change krenge
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## wight updation
#
#
# ![image.png](attachment:image.png)
#
#
#
# - ..
# - yaha n type dikh rha hai wo learning rate hoga
# - ab ek ek node ke weight ko update krenge
# - yaha output  dependency ka chain create ho jata
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - is way mem weight update hota hai
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - classificaiton problem ke liye  loss calculation ke liye [ log loss use krte hai ]
# - regression problem ke liye [ mean square loss ]
#
#
# - yaha dekh skte hai  change ke baad  improvement hua hai
# -  ab hame kb rukna hi iske liye optimizer use krte hai
# - ye optimizer [ gradient decent use hota hai ]
# -
#
# ![image.png](attachment:image.png)
#
#
#
# -
# -  hame  gradient decent  global minima use krna hota hia
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - yha  ek baar forward / bakword hota usko epoch bolte hai
# - 1 epoch = 1 forward propogation  and 1 back propogation

# %% [markdown]
# ----------

# %% [markdown]
# ## Activation fun

# %% [markdown]
# #### Sigmoid fun
#
# - isko use km krte hai qki vanishing gradient problem ho jata
# - regression task me signmoid activation ka use nhi rkte
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - yaha below me dekhenge  to   multiply krne pr km aja rha   jb decimal ya 0 point me multiply kr rhe
# - in case of signmoid me
# - to aise cae me jb hum multiply krte jate hai to back propogation ke case me wo shrink hota jayega
# - then chhota chhota hote dekh ke aur bhi km ho jayega and at the end 0 ho jayega
# - that means res hamesha 0 me ajayega agr epoch badhte jayega
# - hence starting leayer learning bnd ho jata hai qki weight 0 hi  ho jata
#
#
# ![image.png](attachment:image.png)
#
#
# -
# ![image-2.png](attachment:image-2.png)
#
#
# - isse acha Redul use kr lo

# %% [markdown]
# # Types ofr activaiton fun

# %% [markdown]
# ## 1 / Linear Regration
#
# - ye sbse pehle discover hua
# ![image.png](attachment:image.png)
#
#
# - jb value ko 0 -1 ke bich me n rhe
# ![image-2.png](attachment:image-2.png)
#
#
# -  isko hum output layer bs me hi use krte hai
# - agr hidden layer me use kre to ML ka linear regression type ho jayega
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 2. sinbgmoid fun

# %% [markdown]
# -  iska use  bhi  hidden layer me use krne se vanishing gradient probelm occur ho jayega
# - iski jaga relu use kr lete hai
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 3.  Tanh Acti9vation Function
#
# - ye bhi squoch krta  but -1 and +1 ke bich me krta
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - suppose koi case me negative vlaue aagyi  ya 0 value aagyi to us case me
# - pura ek line of network 0 ho jata hai
# - hence no learning yahi dying relu kehlata hi
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5. Leaky Relu  activation fun
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 6. PRelu
# -
#
# ![image.png](attachment:image.png)
#
# -
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##  Swish Activation Fun
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# --------
# ------------

# %% [markdown]
# - ab nural network bahut ho skte to kon sa activaiton fun kaha use kru ye kai8se pta kre
# ![image.png](attachment:image.png)

# %% [markdown]
# # how to choose activaiton fun for each layers
#
#
# - l1 me koi activaiton nhi qki input layer hi
# - mid /L2 me linear activaiton fun  use nhi rkhte  qki liner regression kind ho jayega aur koi acha output nhi deta
# - ab  sigmoid use kiye the L2 me lekin vainishing gradient ka problem ho jata
# - L2 me isliye ReLu use krte [ qki ye scoch bhi kr dete ] , back propogation bhi kroge to dikkat nhi aayegi
# - L2 me Relu , PReLu lga skte
#
# - last output layer me   linear fun / sigmoid lga skte hai
# - softmax

# %% [markdown]
# # Desision Treee

# %% [markdown]
# ## 🌳 Decision Tree in Machine Learning
# ## 1. What is a Decision Tree?
#
# A decision tree is a supervised learning algorithm used for classification and regression.
#
# It works like a flowchart:
#
# **Internal nodes** → represent conditions (tests on features).
#
# **Branches** → represent outcomes of conditions.
#
# **Leaf nodes** → represent final decision/output (class label or value).
#
# 👉 Think of it as a game of “20 Questions” where each question splits possibilities until you reach an answer.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# but in data sets we have multiple columns to kisko leaf kisko root bnayenge to  problem ho jata

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### above   me outlook  ko root q liye ??
#
# iske liye Entropy , information Gain ka formula lgana hota choose krne ke liye

# %% [markdown]
# 2. How It Works (Step by Step)
#
# -> Start with the dataset (features + labels).
#
# -> Choose the best feature to split the data (using measures like Gini Index, Entropy/Information Gain).
#
# -> Split the dataset into subsets based on feature values.
#
# -> Repeat steps 2–3 for each subset until:
#
#         * All data in a node belongs to the same class, or
#
#         *  Maximum depth/stop condition is reached.
#
# -> stop when :
#           * all  data is pure  / The final nodes (leaves) give predictions.
#
#           * max depth is reach [ jb pure result me n pahuch paye  yes /no hota hi ja rha ]

# %% [markdown]
# now  hame column pta lagane ke liye Entropy nikalnege

# %% [markdown]
# ## Entropy (H): measures impurity/disorder in data.
#
# H(S) = - Σ p_i * log2(p_i)
#
#
# where p_i is probability of class i.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Information Gain (IG): reduction in entropy after a split.
#
# IG = Entropy(before split) - Weighted Entropy(after split)
#
#
# Gini Index: another measure of impurity.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# yaha dekh skte ki outlook ka informaiton Gain jyada hai to isko use krenge a  for root as a decesion Tree
#
#
# yaha repeatidly hr ek branch ke liye  entpropy and informaiton gain nikalte jaate and at the end jika max ata usko lete as a root

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
x= np.linspace(0 ,5 , 11)
x 
y= x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot( y , x )

# %%
# label addd kjrna chahta hu 

plt.title("hello")
plt.xlabel("x side ")
plt.ylabel("x side ")
plt.plot( y , x )

# %% [markdown]
#  ab ek hi plot ko chhote chhote  square me  todna  subploting me aata
#
#  subplot(no. rows , no. columns )  jitne me todna hai
#
#  and eke ek ko use krne ke liye plt.subplot( total no. rows , total no. col,  then  no. jo no. ka plot use krna )

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,1)
# Out:
# <Axes: >

# %%
plt.subplot(2,2,2)
# Out:
# <Axes: >

# %% [markdown]
# ab aisi chhote chhote plots me ploting krna ho tb
#
# jo plot me bnana ho us plot ke niche jaake ploting perfomr kr dena

# %%
# jaha jaha plot  krna hai subplot no. ke baad just plot perform kr do 
# jo subplot select krenge wahi paas krenge 
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.plot(x,y)

plt.subplot(2,2,3)
plt.plot(x,y)
plt.subplot(2,2,4)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %% [markdown]
# yah jo white space dekhenge wo hota hai canvas which we not able to select

# %% [markdown]
# object oriented way :  upper hum dekh skte itne saare subplots hai pr ek bhi plot ko hum touch nhi kr skte
# lekin agr un sb subplots ko as a object bna le tb kr skte
#
# isliye yaha object oriendted way aata hai
#
#
#
# isme hamare canvas ka full handle hota

# %% [markdown]
# object oriented way

# %%
fig = plt.figure()  # ye just canvas bna rha

# %%
fig = plt.figure()  #  sb is canvas me axes bnayenge

# yaha hum apne plotka size bna rhe  jo ki percentage me hota hai  =->100 % yaah  0.0 - 1.1 - .1.0  [100]  tk hota 
               # left , bottom , size width , hight 
fig.add_axes( [ 0.1,0.4,0.5 ,0.8])
# Out:
# <Axes: >

# %%
fig = plt.figure()  #  sb is canvas me axes bnayenge

# ab created axes me  kuch plot krwate  
axis1 = fig.add_axes( [ 0.1,0.4,0.5 ,0.8])
# yaha axes ko variable me le liya 

# then usi axess area me hum ploting krte 
axis1.plot(x,y)

# %% [markdown]
#  hum canvas ko over laping kr skte waha isse pehle me ek ke uper ek krke multiple plot perform nhi kr paa rhe the
#
#
#  yaha hum khud hi se direction and access dete jisse kahi bhi ploting kr skte
#
#
#  yaha diferetn difrent ases create krek aage kbhi bhi us name ko acces rkek ploting kr skte  previous wale me jo subplot bna rhe usi ke baad ploting perform krna padta  baad me nhi kr paate

# %%
fig = plt.figure()  #  sb is canvas me axes bnayenge

# ab created axes me  kuch plot krwate  
axis1 = fig.add_axes( [ 0.1,0.4,0.8 ,0.8])
# yaha axes ko variable me le liya 

# then usi axess area me hum ploting krte 
axis1.plot(x,y)


axis2 = fig.add_axes( [ 0.3,0.6,0.5 ,0.5])
 
axis2.plot(x,y)

# %%
fig = plt.figure(figsize=(5,5))  #  sb is canvas me axes bnayenge

# ab created axes me  kuch plot krwate  
axis1 = fig.add_axes( [ 0.1,0.4,0.8 ,0.8])
# yaha axes ko variable me le liya 

# then usi axess area me hum ploting krte 
axis1.plot(x,y)


axis2 = fig.add_axes( [ 0.3,0.6,0.5 ,0.5])
 
axis2.plot(x,y)

# %% [markdown]
# dpi : depth per inch   ye detailing of the pixel ke liye hota hai

# %%
fig = plt.figure(figsize=(5,5), dpi=100)  #  sb is canvas me axes bnayenge

# ab created axes me  kuch plot krwate  
axis1 = fig.add_axes( [ 0.1,0.4,0.8 ,0.8])
# yaha axes ko variable me le liya 

# then usi axess area me hum ploting krte 
axis1.plot(x,y)


axis2 = fig.add_axes( [ 0.3,0.6,0.5 ,0.5])
 
axis2.plot(x,y)

# %% [markdown]
# TYPES OF PLOTS :
#
# 1. scatter plots
# 2. histogram
# 3. boxplot

# %%
plt.scatter(x,y)

# %%
# histogram 

from random import sample 
data = sample(range(1,1000),100)
 
plt.hist(data)
plt.show()

# %%
plt.boxplot(x)
plt.show()

# %% [markdown]
# # plot savig

# %%
fig = plt.figure()
ax = fig.add_axes([0.1 , 0.1 , 0.8 , 0.8])
ax.plot(x,y)

# saving figures
plt.savefig('test.png')

# %% [markdown]
# # working with images

# %%
import matplotlib.image as mpimg 
import numpy as np
img = mpimg.imread('image.png')
img
# Out:
# array([[[0.3372549 , 0.42745098, 0.40392157, 1.        ],
#         [0.3372549 , 0.42745098, 0.40392157, 1.        ],
#         [0.3372549 , 0.42745098, 0.40392157, 1.        ],
#         ...,
#         [0.29803923, 0.42352942, 0.41960785, 1.        ],
#         [0.29411766, 0.41960785, 0.41568628, 1.        ],
#         [0.28235295, 0.40784314, 0.40392157, 1.        ]],
#
#        [[0.3137255 , 0.40392157, 0.38039216, 1.        ],
#         [0.3137255 , 0.40392157, 0.38039216, 1.        ],
#         [0.31764707, 0.40784314, 0.38431373, 1.        ],
#         ...,
#         [0.28235295, 0.40784314, 0.40392157, 1.        ],
#         [0.27450982, 0.40784314, 0.40392157, 1.        ],
#         [0.27450982, 0.4       , 0.39607844, 1.        ]],
#
#        [[0.3254902 , 0.40784314, 0.3882353 , 1.        ],
#         [0.32941177, 0.4117647 , 0.39215687, 1.        ],
#         [0.32941177, 0.4117647 , 0.39215687, 1.        ],
#         ...,
# ...

# %% [markdown]
# img ko dekhna hai

# %%
plt.imshow(img)

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
cropped_img = img[90:400, 100:400]
plt.imshow(cropped_img )
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(210.5), np.float64(71.5), np.float64(-0.5))

# %% [markdown]
# # optional designiing of plot
#
# yaha liens aur ploting ke bahut hi style ho skte hai iske liye online search kr skte

# %%
plt.plot(x,y , color='pink' ,linewidth=5, linestyle='dotted')

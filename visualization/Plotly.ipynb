# %% [markdown]
# # Plotly
#
# pip install plotly
# pip install cufflink

# %%
import seaborn as sns 
import pandas as pd 
import numpy as np
import cufflinks as cf 
from plotly.offline import iplot, init_notebook_mode

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['total_bill'].iplot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 tips['total_bill'].iplot()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cufflinks\plotlytools.py:839, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     837 	if not isinstance(text,list):
#     838 		text=self[text].values
# --> 839 data=df.to_iplot(colors=colors,colorscale=colorscale,kind=kind,interpolation=interpolation,fill=fill,width=width,dash=dash,sortbars=sortbars,keys=keys,
#     840 		bestfit=bestfit,bestfit_colors=bestfit_colors,mean=mean,mean_colors=mean_colors,asDates=asDates,mode=mode,symbol=symbol,size=size,
#     841 		text=text,**kwargs)
#     842 trace_kw=check_kwargs(kwargs,TRACE_KWARGS)
#     843 for trace in data:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cufflinks\plotlytools.py:161, in _to_iplot(self, colors, colorscale, kind, mode, interpolation, symbol, size, fill, width, dash, sortbars, keys, bestfit, bestfit_colors, opacity, mean, mean_colors, asDates, asTimestamp, text, **kwargs)
#     159 	lines_plotly=[Bar(lines[key]).to_plotly_json() for key in keys]
#     160 else:
# --> 161 	lines_plotly=[Scatter(lines[key]).to_plotly_json() for key in keys]
#     162 for trace in lines_plotly:
#     163 	if isinstance(trace['name'],pd.Timestamp):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\_scatter.py:2704, in Scatter.__init__(self, arg, alignmentgroup, cliponaxis, connectgaps, customdata, customdatasrc, dx, dy, error_x, error_y, fill, fillcolor, fillgradient, fillpattern, groupnorm, hoverinfo, hoverinfosrc, hoverlabel, hoveron, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, line, marker, meta, metasrc, mode, name, offsetgroup, opacity, orientation, selected, selectedpoints, showlegend, stackgaps, stackgroup, stream, text, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, uid, uirevision, unselected, visible, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, zorder, **kwargs)
#    2702 self._set_property("legendrank", arg, legendrank)
#    2703 self._set_property("legendwidth", arg, legendwidth)
# -> 2704 self._set_property("line", arg, line)
#    2705 self._set_property("marker", arg, marker)
#    2706 self._set_property("meta", arg, meta)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4422, in BasePlotlyType._set_property(self, name, arg, provided)
#    4416 def _set_property(self, name, arg, provided):
#    4417     """
#    4418     Initialize a property of this object using the provided value
#    4419     or a value popped from the arguments dictionary. If neither
#    4420     is available, do not set the property.
#    4421     """
# -> 4422     _set_property_provided_value(self, name, arg, provided)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4944, in BasePlotlyType.__setitem__(self, prop, value)
#    4942 # ### Handle compound property ###
#    4943 if isinstance(validator, CompoundValidator):
# -> 4944     self._set_compound_prop(prop, value)
#    4946 # ### Handle compound array property ###
#    4947 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5355, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5352 # Import value
#    5353 # ------------
#    5354 validator = self._get_validator(prop)
# -> 5355 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5357 # Save deep copies of current and new states
#    5358 # ------------------------------------------
#    5359 curr_val = self._compound_props.get(prop, None)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:2489, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2486     v = self.data_class()
#    2488 elif isinstance(v, dict):
# -> 2489     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2491 elif isinstance(v, self.data_class):
#    2492     # Copy object
#    2493     v = self.data_class(v)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\scatter\_line.py:306, in Line.__init__(self, arg, backoff, backoffsrc, color, dash, shape, simplify, smoothing, width, **kwargs)
#     304 self._set_property("backoff", arg, backoff)
#     305 self._set_property("backoffsrc", arg, backoffsrc)
# --> 306 self._set_property("color", arg, color)
#     307 self._set_property("dash", arg, dash)
#     308 self._set_property("shape", arg, shape)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4422, in BasePlotlyType._set_property(self, name, arg, provided)
#    4416 def _set_property(self, name, arg, provided):
#    4417     """
#    4418     Initialize a property of this object using the provided value
#    4419     or a value popped from the arguments dictionary. If neither
#    4420     is available, do not set the property.
#    4421     """
# -> 4422     _set_property_provided_value(self, name, arg, provided)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4952, in BasePlotlyType.__setitem__(self, prop, value)
#    4948         self._set_array_prop(prop, value)
#    4950     # ### Handle simple property ###
#    4951     else:
# -> 4952         self._set_prop(prop, value)
#    4953 else:
#    4954     # Make sure properties dict is initialized
#    4955     self._init_props()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5296, in BasePlotlyType._set_prop(self, prop, val)
#    5294         return
#    5295     else:
# -> 5296         raise err
#    5298 # val is None
#    5299 # -----------
#    5300 if val is None:
#    5301     # Check if we should send null update
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5291, in BasePlotlyType._set_prop(self, prop, val)
#    5288 validator = self._get_validator(prop)
#    5290 try:
# -> 5291     val = validator.validate_coerce(val)
#    5292 except ValueError as err:
#    5293     if self._skip_invalid:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:1395, in ColorValidator.validate_coerce(self, v, should_raise)
#    1393     validated_v = self.vc_scalar(v)
#    1394     if validated_v is None and should_raise:
# -> 1395         self.raise_invalid_val(v)
#    1397     v = validated_v
#    1399 return v
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:299, in BaseValidator.raise_invalid_val(self, v, inds)
#     296             for i in inds:
#     297                 name += "[" + str(i) + "]"
# --> 299         raise ValueError(
#     300             """
#     301     Invalid value of type {typ} received for the '{name}' property of {pname}
#     302         Received value: {v}
#     303
#     304 {valid_clr_desc}""".format(
#     305                 name=name,
#     306                 pname=self.parent_name,
#     307                 typ=type_str(v),
#     308                 v=repr(v),
#     309                 valid_clr_desc=self.description(),
#     310             )
#     311         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of scatter.line
#         Received value: 'rgba(255, 153, 51, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color: see https://plotly.com/python/css-colors/ for a list

# %%
tips.groupby('day')['tip'].mean().iplot(kind = 'bar')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3540\2246025421.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 tips.groupby('day')['tip'].mean().iplot(kind = 'bar')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cufflinks\plotlytools.py:839, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     837 	if not isinstance(text,list):
#     838 		text=self[text].values
# --> 839 data=df.to_iplot(colors=colors,colorscale=colorscale,kind=kind,interpolation=interpolation,fill=fill,width=width,dash=dash,sortbars=sortbars,keys=keys,
#     840 		bestfit=bestfit,bestfit_colors=bestfit_colors,mean=mean,mean_colors=mean_colors,asDates=asDates,mode=mode,symbol=symbol,size=size,
#     841 		text=text,**kwargs)
#     842 trace_kw=check_kwargs(kwargs,TRACE_KWARGS)
#     843 for trace in data:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cufflinks\plotlytools.py:159, in _to_iplot(self, colors, colorscale, kind, mode, interpolation, symbol, size, fill, width, dash, sortbars, keys, bestfit, bestfit_colors, opacity, mean, mean_colors, asDates, asTimestamp, text, **kwargs)
#     157 			lines[key]["fillcolor"]=to_rgba(colors[key],kwargs['opacity'] if 'opacity' in kwargs else .3		)
#     158 if 'bar' in kind:
# --> 159 	lines_plotly=[Bar(lines[key]).to_plotly_json() for key in keys]
#     160 else:
#     161 	lines_plotly=[Scatter(lines[key]).to_plotly_json() for key in keys]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\_bar.py:2550, in Bar.__init__(self, arg, alignmentgroup, base, basesrc, cliponaxis, constraintext, customdata, customdatasrc, dx, dy, error_x, error_y, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, insidetextanchor, insidetextfont, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, marker, meta, metasrc, name, offset, offsetgroup, offsetsrc, opacity, orientation, outsidetextfont, selected, selectedpoints, showlegend, stream, text, textangle, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, uid, uirevision, unselected, visible, width, widthsrc, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, zorder, **kwargs)
#    2548 self._set_property("legendrank", arg, legendrank)
#    2549 self._set_property("legendwidth", arg, legendwidth)
# -> 2550 self._set_property("marker", arg, marker)
#    2551 self._set_property("meta", arg, meta)
#    2552 self._set_property("metasrc", arg, metasrc)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4422, in BasePlotlyType._set_property(self, name, arg, provided)
#    4416 def _set_property(self, name, arg, provided):
#    4417     """
#    4418     Initialize a property of this object using the provided value
#    4419     or a value popped from the arguments dictionary. If neither
#    4420     is available, do not set the property.
#    4421     """
# -> 4422     _set_property_provided_value(self, name, arg, provided)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4944, in BasePlotlyType.__setitem__(self, prop, value)
#    4942 # ### Handle compound property ###
#    4943 if isinstance(validator, CompoundValidator):
# -> 4944     self._set_compound_prop(prop, value)
#    4946 # ### Handle compound array property ###
#    4947 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5355, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5352 # Import value
#    5353 # ------------
#    5354 validator = self._get_validator(prop)
# -> 5355 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5357 # Save deep copies of current and new states
#    5358 # ------------------------------------------
#    5359 curr_val = self._compound_props.get(prop, None)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:2489, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2486     v = self.data_class()
#    2488 elif isinstance(v, dict):
# -> 2489     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2491 elif isinstance(v, self.data_class):
#    2492     # Copy object
#    2493     v = self.data_class(v)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\bar\_marker.py:681, in Marker.__init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, color, coloraxis, colorbar, colorscale, colorsrc, cornerradius, line, opacity, opacitysrc, pattern, reversescale, showscale, **kwargs)
#     679 self._set_property("colorsrc", arg, colorsrc)
#     680 self._set_property("cornerradius", arg, cornerradius)
# --> 681 self._set_property("line", arg, line)
#     682 self._set_property("opacity", arg, opacity)
#     683 self._set_property("opacitysrc", arg, opacitysrc)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4422, in BasePlotlyType._set_property(self, name, arg, provided)
#    4416 def _set_property(self, name, arg, provided):
#    4417     """
#    4418     Initialize a property of this object using the provided value
#    4419     or a value popped from the arguments dictionary. If neither
#    4420     is available, do not set the property.
#    4421     """
# -> 4422     _set_property_provided_value(self, name, arg, provided)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4944, in BasePlotlyType.__setitem__(self, prop, value)
#    4942 # ### Handle compound property ###
#    4943 if isinstance(validator, CompoundValidator):
# -> 4944     self._set_compound_prop(prop, value)
#    4946 # ### Handle compound array property ###
#    4947 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5355, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5352 # Import value
#    5353 # ------------
#    5354 validator = self._get_validator(prop)
# -> 5355 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5357 # Save deep copies of current and new states
#    5358 # ------------------------------------------
#    5359 curr_val = self._compound_props.get(prop, None)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:2489, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2486     v = self.data_class()
#    2488 elif isinstance(v, dict):
# -> 2489     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2491 elif isinstance(v, self.data_class):
#    2492     # Copy object
#    2493     v = self.data_class(v)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\bar\marker\_line.py:541, in Line.__init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, color, coloraxis, colorscale, colorsrc, reversescale, width, widthsrc, **kwargs)
#     539 self._set_property("cmid", arg, cmid)
#     540 self._set_property("cmin", arg, cmin)
# --> 541 self._set_property("color", arg, color)
#     542 self._set_property("coloraxis", arg, coloraxis)
#     543 self._set_property("colorscale", arg, colorscale)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4422, in BasePlotlyType._set_property(self, name, arg, provided)
#    4416 def _set_property(self, name, arg, provided):
#    4417     """
#    4418     Initialize a property of this object using the provided value
#    4419     or a value popped from the arguments dictionary. If neither
#    4420     is available, do not set the property.
#    4421     """
# -> 4422     _set_property_provided_value(self, name, arg, provided)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4952, in BasePlotlyType.__setitem__(self, prop, value)
#    4948         self._set_array_prop(prop, value)
#    4950     # ### Handle simple property ###
#    4951     else:
# -> 4952         self._set_prop(prop, value)
#    4953 else:
#    4954     # Make sure properties dict is initialized
#    4955     self._init_props()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5296, in BasePlotlyType._set_prop(self, prop, val)
#    5294         return
#    5295     else:
# -> 5296         raise err
#    5298 # val is None
#    5299 # -----------
#    5300 if val is None:
#    5301     # Check if we should send null update
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5291, in BasePlotlyType._set_prop(self, prop, val)
#    5288 validator = self._get_validator(prop)
#    5290 try:
# -> 5291     val = validator.validate_coerce(val)
#    5292 except ValueError as err:
#    5293     if self._skip_invalid:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:1395, in ColorValidator.validate_coerce(self, v, should_raise)
#    1393     validated_v = self.vc_scalar(v)
#    1394     if validated_v is None and should_raise:
# -> 1395         self.raise_invalid_val(v)
#    1397     v = validated_v
#    1399 return v
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:299, in BaseValidator.raise_invalid_val(self, v, inds)
#     296             for i in inds:
#     297                 name += "[" + str(i) + "]"
# --> 299         raise ValueError(
#     300             """
#     301     Invalid value of type {typ} received for the '{name}' property of {pname}
#     302         Received value: {v}
#     303
#     304 {valid_clr_desc}""".format(
#     305                 name=name,
#     306                 pname=self.parent_name,
#     307                 typ=type_str(v),
#     308                 v=repr(v),
#     309                 valid_clr_desc=self.description(),
#     310             )
#     311         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of bar.marker.line
#         Received value: 'rgba(255, 153, 51, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color: see https://plotly.com/python/css-colors/ for a list
#       - A number that will be interpreted as a color
#         according to bar.marker.line.colorscale
#       - A list or array of any of the above

# %%
tips.iplot(kind = 'scatter', x='total_bill' , y='tip' , mode='markers')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 tips.iplot(kind = 'scatter', x='total_bill' , y='tip' , mode='markers')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cufflinks\plotlytools.py:839, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     837 	if not isinstance(text,list):
#     838 		text=self[text].values
# --> 839 data=df.to_iplot(colors=colors,colorscale=colorscale,kind=kind,interpolation=interpolation,fill=fill,width=width,dash=dash,sortbars=sortbars,keys=keys,
#     840 		bestfit=bestfit,bestfit_colors=bestfit_colors,mean=mean,mean_colors=mean_colors,asDates=asDates,mode=mode,symbol=symbol,size=size,
#     841 		text=text,**kwargs)
#     842 trace_kw=check_kwargs(kwargs,TRACE_KWARGS)
#     843 for trace in data:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cufflinks\plotlytools.py:161, in _to_iplot(self, colors, colorscale, kind, mode, interpolation, symbol, size, fill, width, dash, sortbars, keys, bestfit, bestfit_colors, opacity, mean, mean_colors, asDates, asTimestamp, text, **kwargs)
#     159 	lines_plotly=[Bar(lines[key]).to_plotly_json() for key in keys]
#     160 else:
# --> 161 	lines_plotly=[Scatter(lines[key]).to_plotly_json() for key in keys]
#     162 for trace in lines_plotly:
#     163 	if isinstance(trace['name'],pd.Timestamp):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\_scatter.py:2704, in Scatter.__init__(self, arg, alignmentgroup, cliponaxis, connectgaps, customdata, customdatasrc, dx, dy, error_x, error_y, fill, fillcolor, fillgradient, fillpattern, groupnorm, hoverinfo, hoverinfosrc, hoverlabel, hoveron, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, line, marker, meta, metasrc, mode, name, offsetgroup, opacity, orientation, selected, selectedpoints, showlegend, stackgaps, stackgroup, stream, text, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, uid, uirevision, unselected, visible, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, zorder, **kwargs)
#    2702 self._set_property("legendrank", arg, legendrank)
#    2703 self._set_property("legendwidth", arg, legendwidth)
# -> 2704 self._set_property("line", arg, line)
#    2705 self._set_property("marker", arg, marker)
#    2706 self._set_property("meta", arg, meta)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4422, in BasePlotlyType._set_property(self, name, arg, provided)
#    4416 def _set_property(self, name, arg, provided):
#    4417     """
#    4418     Initialize a property of this object using the provided value
#    4419     or a value popped from the arguments dictionary. If neither
#    4420     is available, do not set the property.
#    4421     """
# -> 4422     _set_property_provided_value(self, name, arg, provided)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4944, in BasePlotlyType.__setitem__(self, prop, value)
#    4942 # ### Handle compound property ###
#    4943 if isinstance(validator, CompoundValidator):
# -> 4944     self._set_compound_prop(prop, value)
#    4946 # ### Handle compound array property ###
#    4947 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5355, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5352 # Import value
#    5353 # ------------
#    5354 validator = self._get_validator(prop)
# -> 5355 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5357 # Save deep copies of current and new states
#    5358 # ------------------------------------------
#    5359 curr_val = self._compound_props.get(prop, None)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:2489, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2486     v = self.data_class()
#    2488 elif isinstance(v, dict):
# -> 2489     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2491 elif isinstance(v, self.data_class):
#    2492     # Copy object
#    2493     v = self.data_class(v)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\scatter\_line.py:306, in Line.__init__(self, arg, backoff, backoffsrc, color, dash, shape, simplify, smoothing, width, **kwargs)
#     304 self._set_property("backoff", arg, backoff)
#     305 self._set_property("backoffsrc", arg, backoffsrc)
# --> 306 self._set_property("color", arg, color)
#     307 self._set_property("dash", arg, dash)
#     308 self._set_property("shape", arg, shape)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4422, in BasePlotlyType._set_property(self, name, arg, provided)
#    4416 def _set_property(self, name, arg, provided):
#    4417     """
#    4418     Initialize a property of this object using the provided value
#    4419     or a value popped from the arguments dictionary. If neither
#    4420     is available, do not set the property.
#    4421     """
# -> 4422     _set_property_provided_value(self, name, arg, provided)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4952, in BasePlotlyType.__setitem__(self, prop, value)
#    4948         self._set_array_prop(prop, value)
#    4950     # ### Handle simple property ###
#    4951     else:
# -> 4952         self._set_prop(prop, value)
#    4953 else:
#    4954     # Make sure properties dict is initialized
#    4955     self._init_props()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5296, in BasePlotlyType._set_prop(self, prop, val)
#    5294         return
#    5295     else:
# -> 5296         raise err
#    5298 # val is None
#    5299 # -----------
#    5300 if val is None:
#    5301     # Check if we should send null update
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5291, in BasePlotlyType._set_prop(self, prop, val)
#    5288 validator = self._get_validator(prop)
#    5290 try:
# -> 5291     val = validator.validate_coerce(val)
#    5292 except ValueError as err:
#    5293     if self._skip_invalid:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:1395, in ColorValidator.validate_coerce(self, v, should_raise)
#    1393     validated_v = self.vc_scalar(v)
#    1394     if validated_v is None and should_raise:
# -> 1395         self.raise_invalid_val(v)
#    1397     v = validated_v
#    1399 return v
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:299, in BaseValidator.raise_invalid_val(self, v, inds)
#     296             for i in inds:
#     297                 name += "[" + str(i) + "]"
# --> 299         raise ValueError(
#     300             """
#     301     Invalid value of type {typ} received for the '{name}' property of {pname}
#     302         Received value: {v}
#     303
#     304 {valid_clr_desc}""".format(
#     305                 name=name,
#     306                 pname=self.parent_name,
#     307                 typ=type_str(v),
#     308                 v=repr(v),
#     309                 valid_clr_desc=self.description(),
#     310             )
#     311         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of scatter.line
#         Received value: 'rgba(255, 153, 51, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color: see https://plotly.com/python/css-colors/ for a list

# %%
tips[['total_bill' , 'day' , ]].iplot(kind = 'box' , x='total_bill', y='day')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 tips[['total_bill' , 'day' , ]].iplot(kind = 'box' , x='total_bill', y='day')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cufflinks\plotlytools.py:911, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     909 for _ in columns:
#     910 	if kind=='box':
# --> 911 		__=Box(y=df[_].values.tolist(),marker=dict(color=clrs[_]),name=_,
#     912 				line=dict(width=width),boxpoints=boxpoints)
#     913 		# 114 - Horizontal Box
#     914 		__['orientation']=orientation
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\_box.py:2990, in Box.__init__(self, arg, alignmentgroup, boxmean, boxpoints, customdata, customdatasrc, dx, dy, fillcolor, hoverinfo, hoverinfosrc, hoverlabel, hoveron, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, jitter, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, line, lowerfence, lowerfencesrc, marker, mean, meansrc, median, mediansrc, meta, metasrc, name, notched, notchspan, notchspansrc, notchwidth, offsetgroup, opacity, orientation, pointpos, q1, q1src, q3, q3src, quartilemethod, sd, sdmultiple, sdsrc, selected, selectedpoints, showlegend, showwhiskers, sizemode, stream, text, textsrc, uid, uirevision, unselected, upperfence, upperfencesrc, visible, whiskerwidth, width, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, zorder, **kwargs)
#    2988 self._set_property("lowerfence", arg, lowerfence)
#    2989 self._set_property("lowerfencesrc", arg, lowerfencesrc)
# -> 2990 self._set_property("marker", arg, marker)
#    2991 self._set_property("mean", arg, mean)
#    2992 self._set_property("meansrc", arg, meansrc)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4422, in BasePlotlyType._set_property(self, name, arg, provided)
#    4416 def _set_property(self, name, arg, provided):
#    4417     """
#    4418     Initialize a property of this object using the provided value
#    4419     or a value popped from the arguments dictionary. If neither
#    4420     is available, do not set the property.
#    4421     """
# -> 4422     _set_property_provided_value(self, name, arg, provided)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4944, in BasePlotlyType.__setitem__(self, prop, value)
#    4942 # ### Handle compound property ###
#    4943 if isinstance(validator, CompoundValidator):
# -> 4944     self._set_compound_prop(prop, value)
#    4946 # ### Handle compound array property ###
#    4947 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5355, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5352 # Import value
#    5353 # ------------
#    5354 validator = self._get_validator(prop)
# -> 5355 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5357 # Save deep copies of current and new states
#    5358 # ------------------------------------------
#    5359 curr_val = self._compound_props.get(prop, None)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:2489, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2486     v = self.data_class()
#    2488 elif isinstance(v, dict):
# -> 2489     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2491 elif isinstance(v, self.data_class):
#    2492     # Copy object
#    2493     v = self.data_class(v)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\graph_objs\box\_marker.py:353, in Marker.__init__(self, arg, angle, color, line, opacity, outliercolor, size, symbol, **kwargs)
#     350 self._validate = kwargs.pop("_validate", True)
#     352 self._set_property("angle", arg, angle)
# --> 353 self._set_property("color", arg, color)
#     354 self._set_property("line", arg, line)
#     355 self._set_property("opacity", arg, opacity)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4422, in BasePlotlyType._set_property(self, name, arg, provided)
#    4416 def _set_property(self, name, arg, provided):
#    4417     """
#    4418     Initialize a property of this object using the provided value
#    4419     or a value popped from the arguments dictionary. If neither
#    4420     is available, do not set the property.
#    4421     """
# -> 4422     _set_property_provided_value(self, name, arg, provided)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:4952, in BasePlotlyType.__setitem__(self, prop, value)
#    4948         self._set_array_prop(prop, value)
#    4950     # ### Handle simple property ###
#    4951     else:
# -> 4952         self._set_prop(prop, value)
#    4953 else:
#    4954     # Make sure properties dict is initialized
#    4955     self._init_props()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5296, in BasePlotlyType._set_prop(self, prop, val)
#    5294         return
#    5295     else:
# -> 5296         raise err
#    5298 # val is None
#    5299 # -----------
#    5300 if val is None:
#    5301     # Check if we should send null update
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\basedatatypes.py:5291, in BasePlotlyType._set_prop(self, prop, val)
#    5288 validator = self._get_validator(prop)
#    5290 try:
# -> 5291     val = validator.validate_coerce(val)
#    5292 except ValueError as err:
#    5293     if self._skip_invalid:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:1395, in ColorValidator.validate_coerce(self, v, should_raise)
#    1393     validated_v = self.vc_scalar(v)
#    1394     if validated_v is None and should_raise:
# -> 1395         self.raise_invalid_val(v)
#    1397     v = validated_v
#    1399 return v
#
# File ~\AppData\Roaming\Python\Python313\site-packages\_plotly_utils\basevalidators.py:299, in BaseValidator.raise_invalid_val(self, v, inds)
#     296             for i in inds:
#     297                 name += "[" + str(i) + "]"
# --> 299         raise ValueError(
#     300             """
#     301     Invalid value of type {typ} received for the '{name}' property of {pname}
#     302         Received value: {v}
#     303
#     304 {valid_clr_desc}""".format(
#     305                 name=name,
#     306                 pname=self.parent_name,
#     307                 typ=type_str(v),
#     308                 v=repr(v),
#     309                 valid_clr_desc=self.description(),
#     310             )
#     311         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of box.marker
#         Received value: 'rgba(255, 153, 51, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color: see https://plotly.com/python/css-colors/ for a list
